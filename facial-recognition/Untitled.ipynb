# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle

# %%
with open("image_arrays.pkl", mode="rb") as opened_file:
    image_arrays = pickle.load(opened_file)

# %%
image_arrays.keys()
# Out:
# dict_keys(['Duvid'])

# %%
a=1
type(a)
# Out:
# int

# %%
with open("database.pkl", mode="rb") as opened_file:
    db = pickle.load(opened_file)

# %%
a={}
a[1]=2
a[1]=3
a
# Out:
# {1: 3}

# %%
print(list(k for k in db))
# Out:
# ['David', 'Aneesh', 'Prazul', 'Justin', 'Jiin', 'Emily']

# %%
del db[list(db.keys())[0]]

# %%
with open("database.pkl", mode="wb") as opened_file:
    pickle.dump(db,opened_file)

# %%
with open("image_arrays.pkl", mode="rb") as opened_file:
    db = pickle.load(opened_file)

# %%
print(db)
# Out:
# {}

# %%
with open("image_arrays.pkl", mode="wb") as opened_file:
    pickle.dump(db,opened_file)

# %%
from camera import take_picture

# %%
img_arr=take_picture()

# %%
img_arr.shape
# Out:
# (480, 640, 3)

# %%
from os import listdir
from os.path import isfile, join
mypath="./pictures/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
onlyfiles
# Out:
# ['Beyonce.jpg', 'Michael_Phelps.jpg', 'Steven_Spielberg.jpg']

# %%
import matplotlib.pyplot as plt

# %%
from celeb_data import *

# %%
mypath="./pictures/"
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
for f in onlyfiles:
    filepath=mypath+f
    name=f[:-4].replace("_"," ")
    if name not in db:
        db[name]=(name,create_celeb(filepath),filepath)
for k in db:
    print(db[k][0],db[k][1].shape,db[k][2])
# Out:
# File already exists:
# 	c:\users\panda\beaverworks\dlibmodels\dlib_models\dlib_face_recognition_resnet_model_v1.dat
# File already exists:
# 	c:\users\panda\beaverworks\dlibmodels\dlib_models\shape_predictor_68_face_landmarks.dat
# Number of faces detected: 1
# File already exists:
# 	c:\users\panda\beaverworks\dlibmodels\dlib_models\dlib_face_recognition_resnet_model_v1.dat
# File already exists:
# 	c:\users\panda\beaverworks\dlibmodels\dlib_models\shape_predictor_68_face_landmarks.dat
# Number of faces detected: 1
# File already exists:
# 	c:\users\panda\beaverworks\dlibmodels\dlib_models\dlib_face_recognition_resnet_model_v1.dat
# File already exists:
# 	c:\users\panda\beaverworks\dlibmodels\dlib_models\shape_predictor_68_face_landmarks.dat
# Number of faces detected: 1
# File already exists:
# 	c:\users\panda\beaverworks\dlibmodels\dlib_models\dlib_face_recognition_resnet_model_v1.dat
# File already exists:
# ...

# %%
# %matplotlib inline

# %%
image=plt.imread(mypath+"Steven_Spielberg.jpg",format='jpg')
plt.imshow(image)
